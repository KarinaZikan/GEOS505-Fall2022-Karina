# %%
# Need to install bmi_nwis if it doesn't exist
# !pip install bmi_nwis

# %% [markdown]
# ### Note you can undo changes pip made using pip uninstall

# %%
import dataretrieval.nwis as nwis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

site_id = '13139510'
start_date = '1970-10-01'
end_date = '2020-09-30'
#site_id = '13185000' Boise River at Twin Springs
#        = '13139510' Big wood at Hailey
#        = '13246000' N. fork of payette near banks
#        = '13042500' Henry's fork near Island Park
#        = '09085000' roaring fork

# %%
dataset = nwis.get_record(sites=site_id, service='dv', start=start_date, end=end_date)
dataset
# Out:
#                            00010_Maximum 00010_Maximum_cd   site_no  \
# datetime
# 1970-10-01 00:00:00+00:00            NaN              NaN  13139510
# 1970-10-02 00:00:00+00:00            NaN              NaN  13139510
# 1970-10-03 00:00:00+00:00            NaN              NaN  13139510
# 1970-10-04 00:00:00+00:00            NaN              NaN  13139510
# 1970-10-05 00:00:00+00:00            NaN              NaN  13139510
# ...                                  ...              ...       ...
# 2020-09-26 00:00:00+00:00            NaN              NaN  13139510
# 2020-09-27 00:00:00+00:00            NaN              NaN  13139510
# 2020-09-28 00:00:00+00:00            NaN              NaN  13139510
# 2020-09-29 00:00:00+00:00            NaN              NaN  13139510
# 2020-09-30 00:00:00+00:00            NaN              NaN  13139510
#
#                            00010_Minimum 00010_Minimum_cd  00010_Mean  \
# datetime
# ...

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset['00060_Mean'].plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
# df_year = 
dataset['00060_Mean'].groupby(dataset.index.year).max().plot()
# Out:
# <AxesSubplot:xlabel='datetime'>
